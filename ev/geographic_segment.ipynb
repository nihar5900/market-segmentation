# %%
from google.colab import drive
drive.mount(r'/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_ro=pd.read_csv("/content/drive/My Drive/Colab Notebooks/Feynn Labs/ev/data/ro_ev_charging_fasility.csv")
df_ro.head()
# Out:
#             State/UT  No of RO's where EV Charging Facility available
# 0     Andhra Pradesh                                               65
# 1  Arunachal Pradesh                                                4
# 2              Assam                                               19
# 3              Bihar                                               26
# 4         Chandigarh                                                4

# %%
df_ro.columns=['State Name', 'No. of RO']

# %%
df_pcs=pd.read_csv("/content/drive/My Drive/Colab Notebooks/Feynn Labs/ev/data/pcs_charging_fasility.csv")
df_pcs.head()
# Out:
#   S. No.           State Name  Number of PCS
# 0      1  Andaman and Nicobar              3
# 1      2       Andhra Pradesh            222
# 2      3    Arunachal Pradesh              9
# 3      4                Assam             48
# 4      5                Bihar             83

# %%
print(len(df_ro), len(df_pcs))
# Out:
# 32 35

# %%
df=pd.merge(df_pcs.drop('S. No.', axis=1), df_ro, on='State Name', how='left')
df
# Out:
#                                            State Name  Number of PCS  \
# 0                                 Andaman and Nicobar              3
# 1                                      Andhra Pradesh            222
# 2                                   Arunachal Pradesh              9
# 3                                               Assam             48
# 4                                               Bihar             83
# 5                                          Chandigarh              6
# 6                                        Chhattisgarh             46
# 7                                               Delhi            539
# 8                                                 Goa             44
# 9                                             Gujarat            170
# 10                                            Haryana            230
# 11                                   Himachal Pradesh             27
# 12                                  Jammu and Kashmir             24
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State Name     35 non-null     object
#  1   Number of PCS  35 non-null     int64
#  2   No. of RO      28 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df.fillna(0, inplace=True)
df
# Out:
#                                            State Name  Number of PCS  \
# 0                                 Andaman and Nicobar              3
# 1                                      Andhra Pradesh            222
# 2                                   Arunachal Pradesh              9
# 3                                               Assam             48
# 4                                               Bihar             83
# 5                                          Chandigarh              6
# 6                                        Chhattisgarh             46
# 7                                               Delhi            539
# 8                                                 Goa             44
# 9                                             Gujarat            170
# 10                                            Haryana            230
# 11                                   Himachal Pradesh             27
# 12                                  Jammu and Kashmir             24
# ...

# %%
df['No. of RO']=df['No. of RO'].apply(lambda x: int(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State Name     35 non-null     object
#  1   Number of PCS  35 non-null     int64
#  2   No. of RO      35 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %%
df['Total']=df['No. of RO']+df['Number of PCS']
df.head()
# Out:
#             State Name  Number of PCS  No. of RO  Total
# 0  Andaman and Nicobar              3          0      3
# 1       Andhra Pradesh            222         65    287
# 2    Arunachal Pradesh              9          4     13
# 3                Assam             48         19     67
# 4                Bihar             83         26    109

# %%
df_top=df.sort_values(['Total', 'Number of PCS'], ascending=[False, False]).iloc[1:11, :]
df_top
# Out:
#         State Name  Number of PCS  No. of RO  Total
# 14       Karnataka            698        100    798
# 18     Maharashtra            660          0    660
# 7            Delhi            539         66    605
# 31   Uttar Pradesh            406        128    534
# 27      Tamil Nadu            439         76    515
# 25       Rajasthan            254        174    428
# 28       Telangana            271        112    383
# 10         Haryana            230        114    344
# 17  Madhya Pradesh            174        167    341
# 1   Andhra Pradesh            222         65    287

# %%
# plt.pie?

# %%
plt.figure(figsize=(7, 7))
sns.set_palette('pastel')
plt.pie(df_top['Total'], labels=df_top['State Name'], autopct='%1.1f%%', counterclock=False, startangle=90,
        pctdistance=0.85,)
plt.axis('equal')

# draw circle
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
# Adding Circle in Pie chart
fig.gca().add_artist(centre_circle)

# %%
df_higw=pd.read_csv("/content/drive/My Drive/Colab Notebooks/Feynn Labs/ev/data/hiway_ev_charging_fasility.csv",
                    index_col='Sl. No', encoding='cp1252')
df_higw
# Out:
#            Category     Expressways/Highways  EV Charging Stations Sanctioned
# Sl. No
# 1       Expressways            Mumbai - Pune                               10
# 2       Expressways     Ahmadabad - Vadodara                               10
# 3       Expressways        Delhi Agra Yamuna                               20
# 4       Expressways         Bengaluru Mysore                               14
# 5       Expressways        Bangaluru-Chennai                               30
# 6       Expressways             Surat-Mumbai                               30
# 7       Expressways             Agra-Lucknow                               40
# 8       Expressways   Eastern Peripheral (A)                               14
# 9       Expressways            Hyderabad ORR                               16
# 1          Highways         Delhi - Srinagar                               80
# 2          Highways          Delhi – Kolkata                              160
# ...
